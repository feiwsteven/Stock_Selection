# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys
import tushare as ts
import webbrowser
import time
import stockstats as st

# %%
df_stock_list_all = ts.get_stock_basics()
df_stock_list_all.reset_index(level=0, inplace=True)
df_stock_list_all_sort_code = df_stock_list_all.sort_values('code')

df_stock_sh = df_stock_list_all_sort_code[df_stock_list_all_sort_code['code']>'600000']
s_stock_sh = df_stock_sh['code']

df_stock_sz = df_stock_list_all_sort_code[df_stock_list_all_sort_code['code']<'100000']
s_stock_sz = df_stock_sz['code']

# %%
#sys.path.append("libs")

#for code in s_stock_sh:
#    print("now loading:" + code)
#    url = 'http://quotes.money.163.com/service/chddata.html?code=0' + code
#    webbrowser.open(url)
#    time.sleep(5)

#for code in s_stock_sz:
#    print("now loading:" + code)
#    url = 'http://quotes.money.163.com/service/chddata.html?code=1 ' + code
#    webbrowser.open(url)
#    time.sleep(5)

# %%
stock_data = ts.get_hist_data('300122')
stock = st.StockDataFrame.retype(stock_data)
stock[['macd','cr']].plot()

# %%
def define_technics():

# %%
plt.show()
